# %% [markdown]
# # Build Rap Database (top 50 songs from 100+ artists)

# %%
import lyricsgenius
import billboard
import pandas as pd

# %%
genius = lyricsgenius.Genius("IWy9kB3GvyUr_r_dslaqRe_-LsRL1G6fdVKdjVpQRK4ooykkaNv-9gLp6dxU1tW4")

# %%
rappers = ['Kanye West', 'Lil Wayne', 'Jay Z', 'Rick Ross', 'Kendrick Lamar', 'Eminem', 'Drake', 'T.I.', '2 Chainz', 'The Game', 'Chance the Rapper', 'André 3000', 'Nicki Minaj', 'Nas', 'Travis Scott', 'Snoop Dogg', 'Young Thug', 'Young Jeezy', '50 Cent', 'Big Sean', 'Future', 'Gucci Mane', 'Meek Mill', 'Lupe Fiasco', 'YG', 'Fabolous', 'Waka Flocka Flame', 'ASAP Rocky', 'Common', 'B.o.B', 'Wiz Khalifa', 'Lil Uzi Vert', 'Jim Jones']

# %%
rappers_2 = ['Raekwon', 'Ludacris', 'Wale', '21 Savage', 'OutKast','DaBaby','Pop Smoke','Tyler the Creator']

# %%
rappers_3 = ['Notorious B.I.G','Tupac','Cardi B','Megan Thee Stallion','J Cole','Lil Uzi Vert','Lil Baby','Nelly','Mos Def','Logic']

# %%
for rapper in rappers_3:
    artist = genius.search_artist(rapper, max_songs=50, sort="popularity")
    for i in range(len(artist.songs)):
        songs.append((artist.songs[i].artist, artist.songs[i].title, artist.songs[i].lyrics))
# Out:
# Searching for songs by Notorious B.I.G...
#
# Changing artist name to 'The Notorious B.I.G.'
# Song 1: "Juicy"
# Song 2: "Big Poppa"
# Song 3: "Suicidal Thoughts"
# Song 4: "Hypnotize"
# Song 5: "Ten Crack Commandments"
# Song 6: "Notorious Thugs"
# Song 7: "Who Shot Ya?"
# Song 8: "Mo’ Money Mo’ Problems"
# Song 9: "Gimme the Loot"
# Song 10: "Everyday Struggle"
# Song 11: "Kick in the Door"
# Song 12: "One More Chance"
# Song 13: "Warning"
# Song 14: "Sky’s The Limit"
# Song 15: "Dead Wrong"
# Song 16: "One More Chance / Stay With Me (Remix)"
# Song 17: "Me & My Bitch"
# Song 18: "The What"
# Song 19: "Party and Bullshit"
# Song 20: "I Got a Story to Tell"
# Song 21: "What’s Beef?"
# Song 22: "Machine Gun Funk"
# Song 23: "Ready To Die"
# Song 24: "Going Back to Cali"
# Song 25: "Niggas Bleed"
# Song 26: "Long Kiss Goodnight"
# Song 27: "You’re Nobody (Til Somebody Kills You)"
# Song 28: "Unbelievable"
# Song 29: "Things Done Changed"
# Song 30: "Fuck You Tonight"
# ...

# %%
more_rappers = ['Soulja Boy','Lauryn Hill','Ice Cube', 'Twista', 'Camron', 'Scarface', 'UGK', 'Rakim', 'LL Cool J', 'Busta Rhymes', 'Big Daddy Kane'] 
more_rappers_3 = ['Kool G Rap', 'Redman', 'Ghostface Killah']

# %%
more_rappers_5 = ['Slick Rick', 'DMX', 'Method Man', 'Jadakiss', 'Joe Budden', 'Pusha T','Kurupt','NWA',"Royce Da 5'9",'Mase']

# %%
more_rappers_2 = ['Childish Gambino','Big Pun','Post Malone','6ix9ine','Kodak Black','Migos','Trippie Redd','Rae Sremmurd','Jay Electronica']
more_rappers_4 = ['Mobb Deep','Method Man','Diddy','The Roots','Big L', 'XXXtentacion','Mac Miller','MF Doom','Run DMC','Public Enemy','Queen Latifah','Fat Joe','Kid Cudi']

# %%
for rapper in more_rappers:
    artist = genius.search_artist(rapper, max_songs=50, sort="popularity")
    for i in range(len(artist.songs)):
        songs.append((artist.songs[i].artist, artist.songs[i].title, artist.songs[i].lyrics))
# Out:
# Searching for songs by Soulja Boy...
#
# Song 1: "Crank That (Soulja Boy)"
# Song 2: "Kiss Me Thru the Phone"
# Song 3: "Pretty Boy Swag"
# Song 4: "Phone Call"
# Song 5: "Beef (Quavo Diss)"
# Song 6: "Turn My Swag On"
# Song 7: "What’s Hannenin"
# Song 8: "Zan With That Lean"
# Song 9: "Hey You There"
# Song 10: "Ugly"
# Song 11: "Whippin My Wrist"
# Song 12: "New Drip"
# Song 13: "Say she luv me"
# Song 14: "Molly"
# Song 15: "Let’s Be Real"
# Song 16: "Blowing Me Kisses"
# Song 17: "Draco"
# Song 18: "Mean Mug"
# Song 19: "Donk"
# Song 20: "Crank Dat"
# Song 21: "Gucci Bandana"
# Song 22: "Goku"
# Song 23: "Turn My Swag On (Remix)"
# Song 24: "30 Thousand 100 Million"
# Song 25: "Speakers Going Hammer"
# Song 26: "Bapes"
# Song 27: "Yahhh!"
# Song 28: "Pow"
# Song 29: "Stephen Curry"
# Song 30: "Conceited"
# Song 31: "Rollin’ [2015]"
# Song 32: "Grammy"
# Song 33: "I Got Me Some Bapes"
# Song 34: "Swag Daddy"
# Song 35: "So Fresh (You Can Suck my Nuts)"
# ...

# %%
for rapper in more_rappers_2:
    artist = genius.search_artist(rapper, max_songs=50, sort="popularity")
    for i in range(len(artist.songs)):
        songs.append((artist.songs[i].artist, artist.songs[i].title, artist.songs[i].lyrics))
# Out:
# Searching for songs by Childish Gambino...
#
# Song 1: "This Is America"
# Song 2: "Redbone"
# Song 3: "V. 3005"
# Song 4: "IV. Sweatpants"
# Song 5: "Bonfire"
# Song 6: "Heartbeat"
# Song 7: "Freaks and Geeks"
# Song 8: "III. Telegraph Ave. (”Oakland” by Lloyd)"
# Song 9: "I. The Worst Guys"
# Song 10: "You See Me"
# Song 11: "Sober"
# Song 12: "Me and Your Mama"
# Song 13: "II. Zealots of Stockholm [Free Information]"
# Song 14: "I. Crawl"
# Song 15: "Feels Like Summer"
# Song 16: "II. Worldstar"
# Song 17: "III. Life: The Biggest Troll [Andrew Auernheimer]"
# Song 18: "That Power"
# Song 19: "L.E.S."
# Song 20: "II. Shadows"
# Song 21: "I. Flight of the Navigator"
# Song 22: "Backpackers"
# Song 23: "Do Ya Like"
# Song 24: "Because the internet Screenplay - Part 1"
# Song 25: "I. The Party"
# Song 26: "II. Earth: The Oldest Computer (The Last Night)"
# Song 27: "I. Pink Toes"
# Song 28: "All the Shine"
# Song 29: "Grindin’ My Whole Life (Rosenberg Freestyle)"
# ...

# %%
for rapper in more_rappers_3:
    artist = genius.search_artist(rapper, max_songs=50, sort="popularity")
    for i in range(len(artist.songs)):
        songs.append((artist.songs[i].artist, artist.songs[i].title, artist.songs[i].lyrics))
# Out:
# Searching for songs by Kool G Rap...
#
# Song 1: "Fast Life"
# Song 2: "Hey Mister Mister"
# Song 3: "It’s a Shame"
# Song 4: "My Life"
# Song 5: "4, 5, 6"
# Song 6: "Take ’Em to War"
# Song 7: "Executioner Style"
# Song 8: "Blowin’ Up in the World"
# Song 9: "The Streets"
# Song 10: "Money On My Brain"
# Song 11: "Ghetto Knows"
# Song 12: "A Thug’s Love Story (Chapter I, II, III)"
# Song 13: "For Da Brothaz"
# Song 14: "Let the Games Begin"
# Song 15: "Men at Work 2020"
# Song 16: "Holla Back"
# Song 17: "Thug For Life"
# Song 18: "Cannon Fire"
# Song 19: "Raw (Extended Alternate  Version)"
# Song 20: "Where You At"
# Song 21: "Home Sweet Funeral Home"
# Song 22: "Mobsta’s"
# Song 23: "One Dark Night"
# Song 24: "Hitman’s Diary"
# Song 25: "Fight Club"
# Song 26: "Da Bosses Lady"
# Song 27: "Cakes"
# Song 28: "My Life (Remix)"
# Song 29: "Popped Off"
# Song 30: "Drama (Bitch Nigga)"
# Song 31: "You Already Know"
# Song 32: "Foul Cats"
# Song 33: "Legendary Street Team"
# ...

# %%
for rapper in more_rappers_4:
    artist = genius.search_artist(rapper, max_songs=50, sort="popularity")
    for i in range(len(artist.songs)):
        songs.append((artist.songs[i].artist, artist.songs[i].title, artist.songs[i].lyrics))
# Out:
# Searching for songs by Mobb Deep...
#
# Song 1: "Shook Ones Part II"
# Song 2: "Survival of the Fittest"
# Song 3: "Hell on Earth (Front Lines)"
# Song 4: "Quiet Storm"
# Song 5: "Quiet Storm (Remix)"
# Song 6: "Shook Ones, Part I"
# Song 7: "Eye for a Eye (Your Beef Is Mines)"
# Song 8: "Drop a Gem on ’Em"
# Song 9: "Give Up the Goods (Just Step)"
# Song 10: "The Start of Your Ending (41st Side)"
# Song 11: "Drink Away the Pain (Situations)"
# Song 12: "Right Back at You"
# Song 13: "Temperature’s Rising"
# Song 14: "It’s Mine"
# Song 15: "Trife Life"
# Song 16: "Cradle to the Grave"
# Song 17: "Up North Trip"
# Song 18: "Hey Luv (Anything)"
# Song 19: "Q.U.—Hectic"
# Song 20: "Still Shinin’"
# Song 21: "The Infamous Prelude"
# Song 22: "The Learning (Burn)"
# Song 23: "Animal Instinct"
# Song 24: "Party Over"
# Song 25: "Give It Up Fast"
# Song 26: "Apostle’s Warning"
# Song 27: "G.O.D. Pt. III"
# Song 28: "Back at You"
# Song 29: "Extortion"
# Song 30: "Just Step (Prelude)"
# ...

# %%
for rapper in more_rappers_5:
    artist = genius.search_artist(rapper, max_songs=50, sort="popularity")
    for i in range(len(artist.songs)):
        songs.append((artist.songs[i].artist, artist.songs[i].title, artist.songs[i].lyrics))
# Out:
# Searching for songs by Slick Rick...
#
# Song 1: "Children’s Story"
# Song 2: "Adults Only"
# Song 3: "Indian Girl - An Adult Story"
# Song 4: "Hey Young World"
# Song 5: "Mona Lisa"
# Song 6: "Street Talkin’"
# Song 7: "Behind Bars"
# Song 8: "Treat Her Like a Prostitute"
# Song 9: "Teenage Love"
# Song 10: "The Ruler’s Back"
# Song 11: "Teacher, Teacher"
# Song 12: "The Moment I Feared"
# Song 13: "Lick the Balls"
# Song 14: "A Love That’s True (Part 1)"
# Song 15: "Behind Bars (Dum Ditty Dum Mix)"
# Song 16: "Sittin’ in My Car"
# Song 17: "Need Some Bad"
# Song 18: "Me & Nas Bring It To You Hardest"
# Song 19: "Memories"
# Song 20: "I Shouldn’t Have Done It"
# Song 21: "I Own America (Part I)"
# Song 22: "Who Rotten ’Em"
# Song 23: "Kill Niggaz"
# Song 24: "2 Way Street"
# Song 25: "Unify"
# Song 26: "Why, Why, Why"
# Song 27: "Kit (What’s the Scoop?)"
# Song 28: "Let’s Get Crazy"
# Song 29: "It’s a Boy"
# Song 30: "Frozen"
# Song 31: "King Piece in the Chess Game"
# ...

# %%
more_rappers_6 = ['Lil Pump','Playboy Carti','Tech N9ne','Machine Gun Kelly','G-Eazy','Joyner Lucas','Lil B','Juicy J','Bow Wow','Chief Keef','Dr Dre',]

# %%
for rapper in more_rappers_6:
    artist = genius.search_artist(rapper, max_songs=50, sort="popularity")
    for i in range(len(artist.songs)):
        songs.append((artist.songs[i].artist, artist.songs[i].title, artist.songs[i].lyrics))
# Out:
# Searching for songs by Lil Pump...
#
# Song 1: "Gucci Gang"
# Song 2: "D Rose"
# Song 3: "ESSKEETIT"
# Song 4: "Boss"
# Song 5: "Flex Like Ouu"
# Song 6: "Molly"
# Song 7: "Lil Pump"
# Song 8: "Drug Addicts"
# Song 9: "Designer"
# Song 10: "Butterfly Doors"
# Song 11: "Be Like Me"
# Song 12: "Crazy"
# Song 13: "Racks on Racks"
# Song 14: "Broke My Wrist"
# Song 15: "Back"
# Song 16: "Iced Out"
# Song 17: "Fuck J. Cole"
# Song 18: "Gucci Gang (Mega Remix)"
# Song 19: "Elementary"
# Song 20: "Finesse the Pack"
# Song 21: "Welcome to the Party"
# Song 22: "Next"
# Song 23: "What U Sayin’"
# Song 24: "Smoke My Dope"
# Song 25: "Movin"
# Song 26: "Youngest Flexer"
# Song 27: "Whitney"
# Song 28: "Multi Millionaire"
# Song 29: "Obama"
# Song 30: "At the Door"
# Song 31: "Fasho Fasho"
# Song 32: "Pinky Ring"
# Song 33: "Drop Out"
# Song 34: "Foreign"
# Song 35: "Life Like Me"
# Song 36: "Off White"
# Song 37: "ION"
# Song 38: "Pose to Do"
# Song 39: "TAKE"
# Song 40: "Lil Pump Had"
# ...

# %%
len(songs)
# Out:
# 5372

# %%
import csv

# note: If you use 'b' for the mode, you will get a TypeError
# under Python3. You can just use 'w' for Python 3

#data=[('smith, bob',2),('carol',3),('ted',4),('alice',5)]

with open('test.csv', 'wb') as test_file:
    file_writer = csv.writer(test_file)
    for i in range(3):
        file_writer.writerow([x[i] for x in songs])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-187-8c060ea39ae5> in <module>
#       9     file_writer = csv.writer(test_file)
#      10     for i in range(3):
# ---> 11         file_writer.writerow([x[i] for x in songs])
#
# TypeError: a bytes-like object is required, not 'str'

# %%
df = pd.DataFrame.from_records(songs, columns =['Artist', 'Song', 'Lyrics'])

# %%
df.to_csv('db.csv', index=False)

# %%
#df = pd.DataFrame([rapper,title,lyrics])

# %%
#df
# Out:
#                                                   0   \
# 0                                         Kanye West
# 1                                              Mercy
# 2  [Intro: Fuzzy Jones]\nWell, it is a weepin' an...
#
#                                                   1   \
# 0                                         Kanye West
# 1                     Father Stretch My Hands, Pt. 1
# 2  [Intro: Pastor T.L. Barrett / Choir & Future]\...
#
#                                                   2   \
# 0                                         Kanye West
# 1                                            Monster
# 2  [Intro: Justin Vernon]\nI shoot the lights out...
#
#                                                   3   \
# 0                                         Kanye West
# 1                                    Ultralight Beam
# 2  [Intro: Samoria Green & Natalie Green]\n(Yes, ...
#
#                                                   4   \
# ...

# %%
new_rappers = ['Fivio Foreign','A Boogie wit da Hoodie','Ugly God','PnB Rock','Kyle']

# %%
new_rappers_2 = ['Ski Mask the Slump God','JID','Lil Skies','YBN Cordae','Blueface','Gunna','Roddy Ricch','Jack Harlow', 'Polo G']

# %%
for rapper in new_rappers_2:
    artist = genius.search_artist(rapper, max_songs=10, sort="popularity")
    for i in range(len(artist.songs)):
        new_songs.append((artist.songs[i].artist, artist.songs[i].title, artist.songs[i].lyrics))
# Out:
# Searching for songs by Ski Mask the Slump God...
#
# Song 1: "Catch Me Outside"
# Song 2: "BabyWipe"
# Song 3: "Take a Step Back"
# Song 4: "Faucet Failure"
# Song 5: "Nuketown"
# Song 6: "Foot Fungus"
# Song 7: "COOLEST MONKEY IN THE JUNGLE"
# Song 8: "Wheres the Blow!"
# Song 9: "LIKE A SOCCER MOM"
# Song 10: "H2O"
#
# Reached user-specified song limit (10).
# Done. Found 10 songs.
# Searching for songs by JID...
#
# Song 1: "151 Rum"
# Song 2: "NEVER"
# Song 3: "Workin Out"
# Song 4: "Off da Zoinkys"
# Song 5: "Slick Talk"
# Song 6: "D/vision"
# Song 7: "Hasta Luego"
# Song 8: "EdEddnEddy"
# Song 9: "Skrawberries"
# Song 10: "LAUDER"
#
# Reached user-specified song limit (10).
# Done. Found 10 songs.
# Searching for songs by Lil Skies...
#
# Song 1: "Red Roses"
# Song 2: "Nowadays"
# Song 3: "Lust"
# Song 4: "Creeping"
# Song 5: "Welcome to the Rodeo"
# Song 6: "​​i"
# Song 7: "Cloudy Skies"
# Song 8: "I Know You"
# Song 9: "Fake"
# Song 10: "Signs of Jealousy"
#
# ...

# %%
df2 = pd.DataFrame.from_records(new_songs, columns =['Artist', 'Song', 'Lyrics'])

# %%
df_final = pd.concat((df,df2), ignore_index = True)
df_final
# Out:
#           Artist                            Song  \
# 0     Kanye West                           Mercy
# 1     Kanye West  Father Stretch My Hands, Pt. 1
# 2     Kanye West                         Monster
# 3     Kanye West                 Ultralight Beam
# 4     Kanye West                         Bound 2
# ...          ...                             ...
# 5507      Polo G                Through da Storm
# 5508      Polo G                       Heartless
# 5509      Polo G                      Battle Cry
# 5510      Polo G                          I Know
# 5511      Polo G                    Be Something
#
#                                                  Lyrics
# 0     [Intro: Fuzzy Jones]\nWell, it is a weepin' an...
# 1     [Intro: Pastor T.L. Barrett / Choir & Future]\...
# 2     [Intro: Justin Vernon]\nI shoot the lights out...
# 3     [Intro: Samoria Green & Natalie Green]\n(Yes, ...
# 4     [Intro: Ponderosa Twins Plus One & Brenda Lee]...
# ...

# %%
df_final.drop_duplicates(inplace=True)

# %%
df_final.to_csv('db.csv', index=False)

# %% [markdown]
# # chart data

# %%
chart = billboard.ChartData('rap-songs')

# %%
chart[24].title
# Out:
# 'Throat Baby (Go Baby)'

# %%
print(chart)
# Out:
# rap-songs chart from 2020-11-28
# -------------------------------
# 1. 'Mood' by 24kGoldn Featuring iann dior
# 2. 'Laugh Now Cry Later' by Drake Featuring Lil Durk
# 3. 'Lemonade' by Internet Money & Gunna Featuring Don Toliver & NAV
# 4. 'For The Night' by Pop Smoke Featuring Lil Baby & DaBaby
# 5. 'WAP' by Cardi B Featuring Megan Thee Stallion
# 6. 'Rockstar' by DaBaby Featuring Roddy Ricch
# 7. 'Said Sum' by Moneybagg Yo
# 8. 'Whats Poppin' by Jack Harlow Featuring DaBaby, Tory Lanez & Lil Wayne
# 9. 'Drankin N Smokin' by Future & Lil Uzi Vert
# 10. 'What You Know Bout Love' by Pop Smoke
# 11. 'Holiday' by Lil Nas X
# 12. 'Stripes Like Burberry' by Future & Lil Uzi Vert
# 13. 'That's It' by Future & Lil Uzi Vert
# 14. 'The Woo' by Pop Smoke Featuring 50 Cent & Roddy Ricch
# 15. 'Rags2Riches' by Rod Wave Featuring ATR Son Son
# 16. 'Real Baby Pluto' by Future & Lil Uzi Vert
# 17. 'Mr. Right Now' by 21 Savage & Metro Boomin Featuring Drake
# ...

# %%
for artist in df:
    artist = genius.search_artist(artist, max_songs=5, sort="popularity")

# %%
for song in artist.songs:
    print(song.lyrics)

# %%
df = pd.read_csv('data/songs.csv')

# %%
df = df[['artist.inverted','track']]
df = df.dropna(axis=0)
df.reset_index(inplace = True)
df.drop('index',axis=1,inplace=True)
df

# %%
music = []
for i in range(len(chart)):
    song = genius.search_song(chart[i].title,chart[i].artist)
    music.append((chart[i].title,chart[i].artist,song.lyrics))

music
# Out:
# Searching for "Mood" by 24kGoldn Featuring iann dior...
# Done.
# Searching for "Laugh Now Cry Later" by Drake Featuring Lil Durk...
# Done.
# Searching for "Lemonade" by Internet Money & Gunna Featuring Don Toliver & NAV...
# Done.
# Searching for "For The Night" by Pop Smoke Featuring Lil Baby & DaBaby...
# Done.
# Searching for "WAP" by Cardi B Featuring Megan Thee Stallion...
# Done.
# Searching for "Rockstar" by DaBaby Featuring Roddy Ricch...
# Done.
# Searching for "Said Sum" by Moneybagg Yo...
# Done.
# Searching for "Whats Poppin" by Jack Harlow Featuring DaBaby, Tory Lanez & Lil Wayne...
# Done.
# Searching for "Drankin N Smokin" by Future & Lil Uzi Vert...
# Done.
# Searching for "What You Know Bout Love" by Pop Smoke...
# Done.
# Searching for "Holiday" by Lil Nas X...
# Done.
# Searching for "Stripes Like Burberry" by Future & Lil Uzi Vert...
# Done.
# Searching for "That's It" by Future & Lil Uzi Vert...
# Done.
# ...

# %%
song.lyrics
# Out:
# '[Chorus]\nSexy lil\' bitch, sexy lil\' ho\nI love the way you walk, love the way you\u2005talk\nLet\u2005a young nigga\u2005come play in your throat\nDeep stroke\u2005your throat \'til I make you choke\nThroat babies, I\'m tryna\u205fgive\u205f\'em\u205fto you\nThroat babies,\u205fI\'m tryna bust\u205fall on you\nSexy lil\' bitch, sexy lil\' ho\nI love the way you walk, love the way you talk\nLet a young nigga come play in your throat\nDeep stroke your throat \'til I make you choke\nThroat babies, I\'m tryna give \'em to you\nThroat babies, I\'m tryna bust all on you\n\n[Verse 1]\nGot a lil\' hundred, that\'s if you want it\nExtra lil\' forty, gotta come right now\nAnd I got beans you bite down\nSuper good head, no cap, gown\nSince the first time, I been fiendin\', couldn\'t even believe it\nHead like that, shit, pussy, don\'t need it\nWhen she get hungry, she eat my semen\nBalls and all, with her mouth, she clean it\nWashing machine trick, ooh\nShawty got mean grip, ooh\nKnow what 
# ...
